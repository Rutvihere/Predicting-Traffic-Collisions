# %%
# !pip install pyspark
# !pip install dill

# %%
# Import required libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import count
from pyspark.sql.functions import to_date, date_format
from pyspark.sql.functions import col
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from datetime import datetime
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import when
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml import Pipeline
from joblib import dump
# from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
# from sklearn.preprocessing import OneHotEncoder
import dill

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create a SparkSession
spark = SparkSession.builder.appName("TrafficCrashPrediction").getOrCreate()

# importing dataset
file_path = "/content/drive/MyDrive/dataset.csv"

# Read the dataset into a DataFrame
df = spark.read.csv(file_path, header=True, inferSchema=True)

# %%
# Show the first few rows of the DataFrame to verify that the data is loaded correctly
df.show(5, truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------+----------------+----------------------+------------------+----------------------+--------------------+-----------------+------------------+--------------------+-------------------------------+--------+------------------+--------------------+-----------+-----------+--------------------------------+----------------------+------------------+-------------+-------------+----------------------+--------------------------------------+--------------------------------------------------------------------------------+---------+----------------+-----------+------------------+--------------+------------------+---------+-----------+--------------+-----------------+---------+------------------------+--------------+--------------+-----------------------+---------------------------+-----------------------------+----------------------+----------------+----------+-----------------+-----------+------------+-------------+----------------------------------------+
# |CRASH_RECORD_ID                                                                                                                 |CRASH_DATE_EST_I|CRASH_DATE            |POSTED_SPEED_LIMIT|TRAFFIC_CONTROL_DEVICE|DEVICE_CONDITION    |WEATHER_CONDITION|LIGHTING_CONDITION|FIRST_CRASH_TYPE    |TRAFFICWAY_TYPE                |LANE_CNT|ALIGNMENT         |ROADWAY_SURFACE_COND|ROAD_DEFECT|REPORT_TYPE|CRASH_TYPE                      |INTERSECTION_RELATED_I|NOT_RIGHT_OF_WAY_I|HIT_AND_RUN_I|DAMAGE       |DATE_POLICE_NOTIFIED  |PRIM_CONTRIBUTORY_CAUSE               |SEC_CONTRIBUTORY_CAUSE                                                          |STREET_NO|STREET_DIRECTION|STREET_NAME|BEAT_OF_OCCURRENCE|PHOTOS_TAKEN_I|STATEMENTS_TAKEN_I|DOORING_I|WORK_ZONE_I|WORK_ZONE_TYPE|WORKERS_PRESENT_I|NUM_UNITS|MOST_SEVERE_INJURY      |INJURIES_TOTAL|INJURIES_FATAL|INJURIES_INCAPACITATING|INJURIES_NON_INCAPACITATING|INJURIES_REPORTED_NOT_EVIDENT|INJURIES_NO_INDICATION|INJURIES_UNKNOWN|CRASH_HOUR|CRASH_DAY_OF_WEEK|CRASH_MONTH|LATITUDE    |LONGITUDE    |LOCATION                                |
# +--------------------------------------------------------------------------------------------------------------------------------+----------------+----------------------+------------------+----------------------+--------------------+-----------------+------------------+--------------------+-------------------------------+--------+------------------+--------------------+-----------+-----------+--------------------------------+----------------------+------------------+-------------+-------------+----------------------+--------------------------------------+--------------------------------------------------------------------------------+---------+----------------+-----------+------------------+--------------+------------------+---------+-----------+--------------+-----------------+---------+------------------------+--------------+--------------+-----------------------+---------------------------+-----------------------------+----------------------+----------------+----------+-----------------+-----------+------------+-------------+----------------------------------------+
# |6c1659069e9c6285a650e70d6f9b574ed5f64c12888479093dfeef179c0344ec6d2057eae224b5c0d5dfc278c0a237f8c22543f07fdef2e4a95a3849871c9345|NULL            |08/18/2023 12:50:00 PM|15                |OTHER                 |FUNCTIONING PROPERLY|CLEAR            |DAYLIGHT          |REAR END            |OTHER                          |NULL    |STRAIGHT AND LEVEL|DRY                 |NO DEFECTS |ON SCENE   |INJURY AND / OR TOW DUE TO CRASH|NULL                  |NULL              |NULL         |OVER $1,500  |08/18/2023 12:55:00 PM|FOLLOWING TOO CLOSELY                 |DISTRACTION - FROM INSIDE VEHICLE                                               |700      |W               |OHARE ST   |1654              |NULL          |NULL              |NULL     |NULL       |NULL          |NULL             |2        |NONINCAPACITATING INJURY|1             |0             |0                      |1                          |0                            |1                     |0               |12        |6                |8          |NULL        |NULL         |NULL                                    |
# |5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4106558b34b8a6d2b81af02cf91b576ecd7ced08ffd10fcfd940a84f7613125b89d33636e6075064e22|NULL            |07/29/2023 02:45:00 PM|30                |TRAFFIC SIGNAL        |FUNCTIONING PROPERLY|CLEAR            |DAYLIGHT          |PARKED MOTOR VEHICLE|DIVIDED - W/MEDIAN (NOT RAISED)|NULL    |STRAIGHT AND LEVEL|DRY                 |NO DEFECTS |ON SCENE   |NO INJURY / DRIVE AWAY          |NULL                  |NULL              |Y            |OVER $1,500  |07/29/2023 02:45:00 PM|FAILING TO REDUCE SPEED TO AVOID CRASH|OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER|2101     |S               |ASHLAND AVE|1235              |NULL          |NULL              |NULL     |NULL       |NULL          |NULL             |4        |NO INDICATION OF INJURY |0             |0             |0                      |0                          |0                            |1                     |0               |14        |7                |7          |41.854120263|-87.665902343|POINT (-87.665902342962 41.854120262952)|
# |61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9cafd3dc7e631b9e1ba8b450a63af12bd90d1d2d9b127ea287f88d32e138a4eeba17799f536c08048934|NULL            |08/18/2023 05:58:00 PM|30                |NO CONTROLS           |NO CONTROLS         |CLEAR            |DAYLIGHT          |PEDALCYCLIST        |NOT DIVIDED                    |NULL    |STRAIGHT AND LEVEL|DRY                 |NO DEFECTS |ON SCENE   |INJURY AND / OR TOW DUE TO CRASH|NULL                  |NULL              |NULL         |$501 - $1,500|08/18/2023 06:01:00 PM|FAILING TO REDUCE SPEED TO AVOID CRASH|UNABLE TO DETERMINE                                                             |3422     |N               |LONG AVE   |1633              |NULL          |NULL              |NULL     |NULL       |NULL          |NULL             |2        |NONINCAPACITATING INJURY|1             |0             |0                      |1                          |0                            |1                     |0               |17        |6                |8          |41.942975745|-87.761883497|POINT (-87.761883496974 41.942975745006)|
# |004cd14d0303a9163aad69a2d7f341b7da2a8572b2ab3378594bfae8ac53dcb604dd8d414f93c290b55862f9f2517ad32e6209cbc8034c2e26eb3c2bc9724390|NULL            |11/26/2019 08:38:00 AM|25                |NO CONTROLS           |NO CONTROLS         |CLEAR            |DAYLIGHT          |PEDESTRIAN          |ONE-WAY                        |NULL    |CURVE ON GRADE    |DRY                 |NO DEFECTS |ON SCENE   |INJURY AND / OR TOW DUE TO CRASH|NULL                  |NULL              |NULL         |OVER $1,500  |11/26/2019 08:38:00 AM|UNABLE TO DETERMINE                   |NOT APPLICABLE                                                                  |5        |W               |TERMINAL ST|1655              |Y             |Y                 |NULL     |NULL       |NULL          |NULL             |2        |FATAL                   |1             |1             |0                      |0                          |0                            |1                     |0               |8         |3                |11         |NULL        |NULL         |NULL                                    |
# |a1d5f0ea90897745365a4cbb06cc60329a120d89753fac2b02d69c9685d9cf7c763870a60abd01484a39ed1e6c09b1ba59f38214c03a83cccde1247f794e0287|NULL            |08/18/2023 10:45:00 AM|20                |NO CONTROLS           |NO CONTROLS         |CLEAR            |DAYLIGHT          |FIXED OBJECT        |OTHER                          |NULL    |STRAIGHT AND LEVEL|DRY                 |NO DEFECTS |ON SCENE   |NO INJURY / DRIVE AWAY          |NULL                  |NULL              |NULL         |OVER $1,500  |08/18/2023 10:48:00 AM|FOLLOWING TOO CLOSELY                 |DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                             |3        |W               |TERMINAL ST|1653              |NULL          |NULL              |NULL     |NULL       |NULL          |NULL             |1        |NO INDICATION OF INJURY |0             |0             |0                      |0                          |0                            |1                     |0               |10        |6                |8          |NULL        |NULL         |NULL                                    |
# +--------------------------------------------------------------------------------------------------------------------------------+----------------+----------------------+------------------+----------------------+--------------------+-----------------+------------------+--------------------+-------------------------------+--------+------------------+--------------------+-----------+-----------+--------------------------------+----------------------+------------------+-------------+-------------+----------------------+--------------------------------------+--------------------------------------------------------------------------------+---------+----------------+-----------+------------------+--------------+------------------+---------+-----------+--------------+-----------------+---------+------------------------+--------------+--------------+-----------------------+---------------------------+-----------------------------+----------------------+----------------+----------+-----------------+-----------+------------+-------------+----------------------------------------+
# only showing top 5 rows

# %%
# Get all column names of the DataFrame
column_names = df.columns

# Print the column names
print("Column Names:")
for column_name in column_names:
    print(column_name)
# Out:
# Column Names:
# CRASH_RECORD_ID
# CRASH_DATE_EST_I
# CRASH_DATE
# POSTED_SPEED_LIMIT
# TRAFFIC_CONTROL_DEVICE
# DEVICE_CONDITION
# WEATHER_CONDITION
# LIGHTING_CONDITION
# FIRST_CRASH_TYPE
# TRAFFICWAY_TYPE
# LANE_CNT
# ALIGNMENT
# ROADWAY_SURFACE_COND
# ROAD_DEFECT
# REPORT_TYPE
# CRASH_TYPE
# INTERSECTION_RELATED_I
# NOT_RIGHT_OF_WAY_I
# HIT_AND_RUN_I
# DAMAGE
# DATE_POLICE_NOTIFIED
# PRIM_CONTRIBUTORY_CAUSE
# SEC_CONTRIBUTORY_CAUSE
# STREET_NO
# STREET_DIRECTION
# STREET_NAME
# BEAT_OF_OCCURRENCE
# PHOTOS_TAKEN_I
# STATEMENTS_TAKEN_I
# DOORING_I
# WORK_ZONE_I
# WORK_ZONE_TYPE
# WORKERS_PRESENT_I
# NUM_UNITS
# MOST_SEVERE_INJURY
# INJURIES_TOTAL
# INJURIES_FATAL
# INJURIES_INCAPACITATING
# INJURIES_NON_INCAPACITATING
# INJURIES_REPORTED_NOT_EVIDENT
# INJURIES_NO_INDICATION
# INJURIES_UNKNOWN
# CRASH_HOUR
# CRASH_DAY_OF_WEEK
# CRASH_MONTH
# LATITUDE
# LONGITUDE
# LOCATION

# %%
# Select the required columns from the original DataFrame
selected_columns_df = df.select("CRASH_DATE", "WEATHER_CONDITION", "LIGHTING_CONDITION",
                                "ROADWAY_SURFACE_COND", "STREET_NAME",
                                "CRASH_DAY_OF_WEEK", "CRASH_MONTH")

# Show the selected columns DataFrame

selected_columns_df.show()
selected_columns_df.count()
# Out:
# +--------------------+-----------------+--------------------+--------------------+----------------+-----------------+-----------+
# |          CRASH_DATE|WEATHER_CONDITION|  LIGHTING_CONDITION|ROADWAY_SURFACE_COND|     STREET_NAME|CRASH_DAY_OF_WEEK|CRASH_MONTH|
# +--------------------+-----------------+--------------------+--------------------+----------------+-----------------+-----------+
# |08/18/2023 12:50:...|            CLEAR|            DAYLIGHT|                 DRY|        OHARE ST|                6|          8|
# |07/29/2023 02:45:...|            CLEAR|            DAYLIGHT|                 DRY|     ASHLAND AVE|                7|          7|
# |08/18/2023 05:58:...|            CLEAR|            DAYLIGHT|                 DRY|        LONG AVE|                6|          8|
# |11/26/2019 08:38:...|            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                3|         11|
# |08/18/2023 10:45:...|            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                6|          8|
# |07/29/2023 01:00:...|            CLEAR|            DAYLIGHT|             UNKNOWN|     LA SALLE DR|                7|          7|
# |02/06/2023 05:30:...|            CLEAR|DARKNESS, LIGHTED...|                 DRY|     TERMINAL ST|                2|          2|
# |08/13/2023 01:30:...|            CLEAR|            DAYLIGHT|                 DRY|    PROSPECT AVE|                1|          8|
# |08/13/2023 12:11:...|            CLEAR|DARKNESS, LIGHTED...|                 DRY|   WENTWORTH AVE|                1|          8|
# |01/31/2022 07:45:...|            CLEAR|            DARKNESS|                 DRY|      GLADYS AVE|                2|          1|
# |01/01/2022 04:32:...|             SNOW|DARKNESS, LIGHTED...|       SNOW OR SLUSH|PARKING LOT E ST|                7|          1|
# |09/20/2023 11:00:...|            CLEAR|            DAYLIGHT|                 DRY|    BALMORAL AVE|                4|          9|
# |10/09/2023 07:15:...|            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                2|         10|
# |07/29/2023 02:30:...|          UNKNOWN|             UNKNOWN|             UNKNOWN|         47TH ST|                7|          7|
# |07/29/2023 12:50:...|            CLEAR|            DARKNESS|             UNKNOWN|  CALIFORNIA AVE|                7|          7|
# |09/20/2023 12:35:...|            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                4|          9|
# |09/20/2023 04:45:...|            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                4|          9|
# |09/20/2023 09:15:...|            CLEAR|DARKNESS, LIGHTED...|                 DRY|PARKING LOT E ST|                4|          9|
# |10/18/2020 03:58:...|             RAIN|            DAYLIGHT|                 WET|         89TH ST|                1|         10|
# |12/09/2021 10:30:...|            CLEAR|            DAYLIGHT|                 DRY|        OHARE ST|                5|         12|
# +--------------------+-----------------+--------------------+--------------------+----------------+-----------------+-----------+
# only showing top 20 rows
# 820587

# %%
# Get all distinct values
distinct_lighting_conditions = selected_columns_df.select('LIGHTING_CONDITION').distinct()

# Show the distinct values
distinct_lighting_conditions.show(truncate=False)
print(distinct_lighting_conditions.count())
# Out:
# +----------------------+
# |LIGHTING_CONDITION    |
# +----------------------+
# |DAWN                  |
# |DAYLIGHT              |
# |DUSK                  |
# |UNKNOWN               |
# |DARKNESS, LIGHTED ROAD|
# |DARKNESS              |
# +----------------------+
#
# 6

# %%
# getting column data types
selected_columns_df.printSchema()
# Out:
# root
#  |-- CRASH_DATE: string (nullable = true)
#  |-- WEATHER_CONDITION: string (nullable = true)
#  |-- LIGHTING_CONDITION: string (nullable = true)
#  |-- ROADWAY_SURFACE_COND: string (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#  |-- CRASH_DAY_OF_WEEK: integer (nullable = true)
#  |-- CRASH_MONTH: integer (nullable = true)

# %%
# Define a function to parse and reformat dates
def parse_and_reformat(date_str):
    try:
        # Attempt to parse date with first format
        return datetime.strptime(date_str, "%m/%d/%Y %I:%M:%S %p").strftime("%m/%d/%Y")
    except ValueError:
        try:
            # Attempt to parse date with second format
            return datetime.strptime(date_str, "%m-%d-%Y %I:%M:%S %p").strftime("%m/%d/%Y")
        except ValueError:
            # Return None for invalid formats
            return None

# Register the function as a UDF
parse_and_reformat_udf = udf(parse_and_reformat, StringType())

# %%
# Apply the UDF to create a new column with standardized date format
cleaned_df = selected_columns_df.withColumn("CRASH_DATE_STANDARDIZED", parse_and_reformat_udf("CRASH_DATE"))

# Drop the original 'CRASH_DATE' column
cleaned_df = cleaned_df.drop("CRASH_DATE")

# Drop rows with null values in the new column
cleaned_df = cleaned_df.dropna(subset=["CRASH_DATE_STANDARDIZED"])

# Show the updated DataFrame
cleaned_df.show()
# Out:
# +-----------------+--------------------+--------------------+----------------+-----------------+-----------+-----------------------+
# |WEATHER_CONDITION|  LIGHTING_CONDITION|ROADWAY_SURFACE_COND|     STREET_NAME|CRASH_DAY_OF_WEEK|CRASH_MONTH|CRASH_DATE_STANDARDIZED|
# +-----------------+--------------------+--------------------+----------------+-----------------+-----------+-----------------------+
# |            CLEAR|            DAYLIGHT|                 DRY|        OHARE ST|                6|          8|             08/18/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|     ASHLAND AVE|                7|          7|             07/29/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|        LONG AVE|                6|          8|             08/18/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                3|         11|             11/26/2019|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                6|          8|             08/18/2023|
# |            CLEAR|            DAYLIGHT|             UNKNOWN|     LA SALLE DR|                7|          7|             07/29/2023|
# |            CLEAR|DARKNESS, LIGHTED...|                 DRY|     TERMINAL ST|                2|          2|             02/06/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|    PROSPECT AVE|                1|          8|             08/13/2023|
# |            CLEAR|DARKNESS, LIGHTED...|                 DRY|   WENTWORTH AVE|                1|          8|             08/13/2023|
# |            CLEAR|            DARKNESS|                 DRY|      GLADYS AVE|                2|          1|             01/31/2022|
# |             SNOW|DARKNESS, LIGHTED...|       SNOW OR SLUSH|PARKING LOT E ST|                7|          1|             01/01/2022|
# |            CLEAR|            DAYLIGHT|                 DRY|    BALMORAL AVE|                4|          9|             09/20/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                2|         10|             10/09/2023|
# |          UNKNOWN|             UNKNOWN|             UNKNOWN|         47TH ST|                7|          7|             07/29/2023|
# |            CLEAR|            DARKNESS|             UNKNOWN|  CALIFORNIA AVE|                7|          7|             07/29/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                4|          9|             09/20/2023|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                4|          9|             09/20/2023|
# |            CLEAR|DARKNESS, LIGHTED...|                 DRY|PARKING LOT E ST|                4|          9|             09/20/2023|
# |             RAIN|            DAYLIGHT|                 WET|         89TH ST|                1|         10|             10/18/2020|
# |            CLEAR|            DAYLIGHT|                 DRY|        OHARE ST|                5|         12|             12/09/2021|
# +-----------------+--------------------+--------------------+----------------+-----------------+-----------+-----------------------+
# only showing top 20 rows

# %%
# Convert string column to date format
cleaned_df = cleaned_df.withColumn("CRASH_DATE_STANDARDIZED", to_date(cleaned_df["CRASH_DATE_STANDARDIZED"], "MM/dd/yyyy"))

# Show the updated DataFrame
cleaned_df.show()

cleaned_df.printSchema()
# Out:
# +-----------------+--------------------+--------------------+----------------+-----------------+-----------+-----------------------+
# |WEATHER_CONDITION|  LIGHTING_CONDITION|ROADWAY_SURFACE_COND|     STREET_NAME|CRASH_DAY_OF_WEEK|CRASH_MONTH|CRASH_DATE_STANDARDIZED|
# +-----------------+--------------------+--------------------+----------------+-----------------+-----------+-----------------------+
# |            CLEAR|            DAYLIGHT|                 DRY|        OHARE ST|                6|          8|             2023-08-18|
# |            CLEAR|            DAYLIGHT|                 DRY|     ASHLAND AVE|                7|          7|             2023-07-29|
# |            CLEAR|            DAYLIGHT|                 DRY|        LONG AVE|                6|          8|             2023-08-18|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                3|         11|             2019-11-26|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                6|          8|             2023-08-18|
# |            CLEAR|            DAYLIGHT|             UNKNOWN|     LA SALLE DR|                7|          7|             2023-07-29|
# |            CLEAR|DARKNESS, LIGHTED...|                 DRY|     TERMINAL ST|                2|          2|             2023-02-06|
# |            CLEAR|            DAYLIGHT|                 DRY|    PROSPECT AVE|                1|          8|             2023-08-13|
# |            CLEAR|DARKNESS, LIGHTED...|                 DRY|   WENTWORTH AVE|                1|          8|             2023-08-13|
# |            CLEAR|            DARKNESS|                 DRY|      GLADYS AVE|                2|          1|             2022-01-31|
# |             SNOW|DARKNESS, LIGHTED...|       SNOW OR SLUSH|PARKING LOT E ST|                7|          1|             2022-01-01|
# |            CLEAR|            DAYLIGHT|                 DRY|    BALMORAL AVE|                4|          9|             2023-09-20|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                2|         10|             2023-10-09|
# |          UNKNOWN|             UNKNOWN|             UNKNOWN|         47TH ST|                7|          7|             2023-07-29|
# |            CLEAR|            DARKNESS|             UNKNOWN|  CALIFORNIA AVE|                7|          7|             2023-07-29|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                4|          9|             2023-09-20|
# |            CLEAR|            DAYLIGHT|                 DRY|     TERMINAL ST|                4|          9|             2023-09-20|
# |            CLEAR|DARKNESS, LIGHTED...|                 DRY|PARKING LOT E ST|                4|          9|             2023-09-20|
# |             RAIN|            DAYLIGHT|                 WET|         89TH ST|                1|         10|             2020-10-18|
# |            CLEAR|            DAYLIGHT|                 DRY|        OHARE ST|                5|         12|             2021-12-09|
# +-----------------+--------------------+--------------------+----------------+-----------------+-----------+-----------------------+
# only showing top 20 rows
#
# root
#  |-- WEATHER_CONDITION: string (nullable = true)
#  |-- LIGHTING_CONDITION: string (nullable = true)
#  |-- ROADWAY_SURFACE_COND: string (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#  |-- CRASH_DAY_OF_WEEK: integer (nullable = true)
#  |-- CRASH_MONTH: integer (nullable = true)
#  |-- CRASH_DATE_STANDARDIZED: date (nullable = true)

# %%
# Number of rows in the DataFrame
total_rows = cleaned_df.count()
print("Number of rows in the DataFrame:", total_rows)

# Number of non-null values in the column 'CRASH_DATE_STANDARDIZED'
non_null_values = cleaned_df.filter(cleaned_df.CRASH_DATE_STANDARDIZED.isNotNull()).count()
print("Number of non-null values in 'CRASH_DATE_STANDARDIZED' column:", non_null_values)

# Number of distinct values in the column 'CRASH_DATE_STANDARDIZED'
distinct_values_count = cleaned_df.select("CRASH_DATE_STANDARDIZED").distinct().count()
print("Number of distinct values in 'CRASH_DATE_STANDARDIZED' column:", distinct_values_count)
# Out:
# Number of rows in the DataFrame: 820587
# Number of non-null values in 'CRASH_DATE_STANDARDIZED' column: 820587
# Number of distinct values in 'CRASH_DATE_STANDARDIZED' column: 3203

# %%
# creating a new data frame with 3 columns: "CRASH_DATE_STANDARDIZED", "STREET_NAME", and a new column "NUMBER_OF_ACCIDENTS"

# Group by 'CRASH_DATE_STANDARDIZED' and 'STREET_NAME', and count the number of occurrences
aggregated_df = cleaned_df.groupBy("CRASH_DATE_STANDARDIZED", "STREET_NAME").agg(F.count("*").alias("NUMBER_OF_ACCIDENTS"))

# Show the aggregated DataFrame
aggregated_df.show()
# Out:
# +-----------------------+--------------------+-------------------+
# |CRASH_DATE_STANDARDIZED|         STREET_NAME|NUMBER_OF_ACCIDENTS|
# +-----------------------+--------------------+-------------------+
# |             2023-09-01|         TERMINAL ST|                  5|
# |             2023-09-29|            OHARE ST|                  3|
# |             2021-08-25|       FULLERTON AVE|                  2|
# |             2018-06-18|             67TH ST|                  1|
# |             2020-08-12|            OHARE ST|                  2|
# |             2021-11-02|    STONY ISLAND AVE|                  6|
# |             2022-09-08|             35TH ST|                  4|
# |             2019-01-24|         WESTERN AVE|                 12|
# |             2022-04-17|           DAMEN AVE|                  2|
# |             2020-10-28|          ONTARIO ST|                  1|
# |             2018-10-07|      SACRAMENTO AVE|                  2|
# |             2017-12-28|         DIVISION ST|                  2|
# |             2022-11-12|             75TH ST|                  1|
# |             2021-11-14|          SEELEY AVE|                  1|
# |             2017-10-11|DR MARTIN LUTHER ...|                  1|
# |             2018-05-05|            BELL AVE|                  1|
# |             2019-09-19|         CENTRAL AVE|                  6|
# |             2018-09-04|             47TH ST|                  4|
# |             2022-09-26|    PARKING LOT C ST|                  1|
# |             2020-04-25|     CALIFORNIA BLVD|                  1|
# +-----------------------+--------------------+-------------------+
# only showing top 20 rows

# %%
# Order the DataFrame by 'CRASH_DATE_STANDARDIZED' in Ascending order
sorted_df = aggregated_df.orderBy('CRASH_DATE_STANDARDIZED')

# Show all records in ascending order of date
sorted_df.show()
# Out:
# +-----------------------+--------------------+-------------------+
# |CRASH_DATE_STANDARDIZED|         STREET_NAME|NUMBER_OF_ACCIDENTS|
# +-----------------------+--------------------+-------------------+
# |             2013-03-03|          FOSTER AVE|                  1|
# |             2013-06-01|          PRATT BLVD|                  1|
# |             2014-01-18|             LAKE ST|                  1|
# |             2014-01-21|        EXCHANGE AVE|                  1|
# |             2014-02-24|     SACRAMENTO BLVD|                  1|
# |             2014-06-25|          PULASKI RD|                  1|
# |             2014-08-20|             79TH ST|                  1|
# |             2014-11-11|           DEVON AVE|                  1|
# |             2015-01-10|            AVENUE L|                  1|
# |             2015-01-17|          CLINTON ST|                  1|
# |             2015-02-13|          ONTARIO ST|                  1|
# |             2015-02-23|       FULLERTON AVE|                  1|
# |             2015-04-06|         ASHLAND AVE|                  1|
# |             2015-04-15|          PULASKI RD|                  1|
# |             2015-04-16|DR MARTIN LUTHER ...|                  1|
# |             2015-05-15| FOREST PRESERVE AVE|                  1|
# |             2015-05-20|       SPAULDING AVE|                  1|
# |             2015-05-25|          CICERO AVE|                  1|
# |             2015-06-01|            CLARK ST|                  1|
# |             2015-06-22|          ELSTON AVE|                  1|
# +-----------------------+--------------------+-------------------+
# only showing top 20 rows

# %%
# Filter records with number of accidents more than 15
filtered_df = sorted_df.filter(col('NUMBER_OF_ACCIDENTS') > 15)

# Show filtered records
filtered_df.show(1000)
# Out:
# +-----------------------+--------------+-------------------+
# |CRASH_DATE_STANDARDIZED|   STREET_NAME|NUMBER_OF_ACCIDENTS|
# +-----------------------+--------------+-------------------+
# |             2017-09-15|    CICERO AVE|                 20|
# |             2017-10-06|    HALSTED ST|                 16|
# |             2017-10-20|   WESTERN AVE|                 17|
# |             2017-11-02|    HALSTED ST|                 16|
# |             2017-12-21|   WESTERN AVE|                 16|
# |             2017-12-28|   WESTERN AVE|                 17|
# |             2018-01-02|IRVING PARK RD|                 16|
# |             2018-01-05|   WESTERN AVE|                 20|
# |             2018-01-19|   WESTERN AVE|                 17|
# |             2018-02-05|    CICERO AVE|                 17|
# |             2018-03-23|   WESTERN AVE|                 16|
# |             2018-03-23|    PULASKI RD|                 16|
# |             2018-05-10|   ASHLAND AVE|                 20|
# |             2018-05-23|   WESTERN AVE|                 18|
# |             2018-06-14|   WESTERN AVE|                 16|
# |             2018-06-15|   WESTERN AVE|                 16|
# |             2018-06-22|    PULASKI RD|                 19|
# |             2018-06-29|   WESTERN AVE|                 19|
# |             2018-07-02|   ASHLAND AVE|                 21|
# |             2018-07-25|    CICERO AVE|                 17|
# |             2018-07-26|    PULASKI RD|                 17|
# |             2018-07-27|   WESTERN AVE|                 17|
# |             2018-08-01|   WESTERN AVE|                 18|
# |             2018-09-14|   WESTERN AVE|                 18|
# |             2018-09-24|   WESTERN AVE|                 18|
# |             2018-09-29|    PULASKI RD|                 16|
# |             2018-10-15|    PULASKI RD|                 16|
# |             2018-11-15|   WESTERN AVE|                 18|
# |             2018-11-27|   WESTERN AVE|                 16|
# |             2018-12-13|   WESTERN AVE|                 17|
# |             2018-12-15|    HALSTED ST|                 16|
# |             2018-12-21|   ASHLAND AVE|                 17|
# |             2019-01-04|    PULASKI RD|                 17|
# |             2019-01-29|   WESTERN AVE|                 16|
# |             2019-02-07|   WESTERN AVE|                 16|
# |             2019-03-15|    PULASKI RD|                 17|
# |             2019-04-27|    PULASKI RD|                 17|
# |             2019-05-01|   ASHLAND AVE|                 16|
# |             2019-05-07|   WESTERN AVE|                 16|
# |             2019-05-09|    PULASKI RD|                 18|
# |             2019-05-10|    PULASKI RD|                 16|
# |             2019-05-13|    CICERO AVE|                 18|
# |             2019-05-14|   WESTERN AVE|                 17|
# |             2019-06-29|    CICERO AVE|                 16|
# |             2019-07-02|    HALSTED ST|                 16|
# |             2019-08-02|   WESTERN AVE|                 16|
# |             2019-09-20|   WESTERN AVE|                 19|
# |             2019-09-21|   WESTERN AVE|                 18|
# |             2019-09-25|   WESTERN AVE|                 18|
# |             2019-10-10|   WESTERN AVE|                 16|
# |             2019-10-24|   WESTERN AVE|                 16|
# |             2019-11-01|   WESTERN AVE|                 16|
# |             2019-11-04|    CICERO AVE|                 16|
# |             2020-01-10|   WESTERN AVE|                 17|
# |             2020-01-21|   WESTERN AVE|                 16|
# |             2020-02-14|   WESTERN AVE|                 19|
# |             2020-02-21|   WESTERN AVE|                 22|
# |             2020-05-23|    CICERO AVE|                 17|
# |             2020-11-24|   WESTERN AVE|                 18|
# |             2020-12-11|   ASHLAND AVE|                 16|
# |             2021-02-03|   WESTERN AVE|                 17|
# |             2021-04-27|    HALSTED ST|                 16|
# |             2021-05-07|   WESTERN AVE|                 22|
# |             2021-05-21|    CICERO AVE|                 16|
# |             2021-05-26|   WESTERN AVE|                 17|
# |             2021-05-28|   WESTERN AVE|                 16|
# |             2021-05-28|    PULASKI RD|                 16|
# |             2021-06-04|    PULASKI RD|                 16|
# |             2021-06-04|   ASHLAND AVE|                 18|
# |             2021-06-17|   ASHLAND AVE|                 16|
# |             2021-06-18|   WESTERN AVE|                 16|
# |             2021-06-26|    PULASKI RD|                 16|
# |             2021-07-07|    PULASKI RD|                 16|
# |             2021-07-09|   WESTERN AVE|                 16|
# |             2021-08-09|   WESTERN AVE|                 16|
# |             2021-08-27|   WESTERN AVE|                 16|
# |             2021-09-17|    PULASKI RD|                 16|
# |             2021-10-01|   WESTERN AVE|                 17|
# |             2021-11-08|   ASHLAND AVE|                 16|
# |             2021-11-12|   ASHLAND AVE|                 16|
# |             2021-12-04|    CICERO AVE|                 16|
# |             2021-12-10|    KEDZIE AVE|                 17|
# |             2021-12-23|   WESTERN AVE|                 16|
# |             2022-01-31|   WESTERN AVE|                 16|
# |             2022-05-02|   ASHLAND AVE|                 16|
# |             2022-05-13|   WESTERN AVE|                 18|
# |             2022-05-14|   WESTERN AVE|                 16|
# |             2022-05-20|   WESTERN AVE|                 17|
# |             2022-09-02|   ASHLAND AVE|                 17|
# |             2022-09-16|    HALSTED ST|                 17|
# |             2022-09-16|    PULASKI RD|                 21|
# |             2022-10-01|   WESTERN AVE|                 16|
# |             2022-11-04|   WESTERN AVE|                 16|
# |             2022-12-09|    PULASKI RD|                 16|
# |             2022-12-09|   WESTERN AVE|                 19|
# |             2022-12-30|   WESTERN AVE|                 16|
# |             2022-12-31|    CICERO AVE|                 16|
# |             2023-01-11|   WESTERN AVE|                 17|
# |             2023-05-13|    CICERO AVE|                 17|
# |             2023-06-27|   WESTERN AVE|                 16|
# |             2023-08-11|   WESTERN AVE|                 17|
# |             2023-08-28|    CICERO AVE|                 16|
# |             2023-08-31|    PULASKI RD|                 16|
# |             2023-09-01|    PULASKI RD|                 16|
# |             2023-09-11|    PULASKI RD|                 19|
# |             2023-10-13|   WESTERN AVE|                 18|
# |             2023-10-17|    PULASKI RD|                 16|
# |             2023-11-01|   WESTERN AVE|                 16|
# |             2023-12-01|    PULASKI RD|                 18|
# |             2023-12-22|    PULASKI RD|                 16|
# |             2024-02-03|    CICERO AVE|                 16|
# |             2024-03-12|   WESTERN AVE|                 16|
# |             2024-03-18|   WESTERN AVE|                 17|
# +-----------------------+--------------+-------------------+

# %%
# making third dataframe by merging the 2 dfs: 'cleaned_df' and 'aggregated_df'

# Perform a join operation between cleaned_df and aggregated_df
final_df = cleaned_df.join(aggregated_df, ['CRASH_DATE_STANDARDIZED', 'STREET_NAME'], 'left_outer')

# Show the final DataFrame
final_df.show(1000)
# Out:
# +-----------------------+--------------------+-----------------+--------------------+--------------------+-----------------+-----------+-------------------+
# |CRASH_DATE_STANDARDIZED|         STREET_NAME|WEATHER_CONDITION|  LIGHTING_CONDITION|ROADWAY_SURFACE_COND|CRASH_DAY_OF_WEEK|CRASH_MONTH|NUMBER_OF_ACCIDENTS|
# +-----------------------+--------------------+-----------------+--------------------+--------------------+-----------------+-----------+-------------------+
# |             2015-08-14|       LAKE PARK AVE|             RAIN|DARKNESS, LIGHTED...|                 WET|                6|          8|                  1|
# |             2015-08-21|             LAKE ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|
# |             2015-09-03|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|
# |             2015-09-08|       WENTWORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|
# |             2015-09-20|         LINCOLN AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  1|
# |             2015-09-29|             TROY ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|
# |             2015-10-07|          CICERO AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|         10|                  2|
# |             2015-10-10|   COTTAGE GROVE AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|         10|                  2|
# |             2015-10-12|          PAULINA ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|         10|                  1|
# |             2015-10-14|        MONTEREY AVE|            CLEAR|            DARKNESS|                 DRY|                4|         10|                  1|
# |             2015-10-22|             83RD ST|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                5|         10|                  1|
# |             2015-10-25|       LAKE SHORE DR|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|         10|                  2|
# |             2015-11-03|             15TH PL|            CLEAR|            DAYLIGHT|                 DRY|                3|         11|                  1|
# |             2015-11-03|           CERMAK RD|            CLEAR|            DAYLIGHT|                 DRY|                3|         11|                  2|
# |             2015-11-07|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                7|         11|                  5|
# |             2015-11-09|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                2|         11|                  1|
# |             2015-11-17|             63RD ST|             RAIN|            DAYLIGHT|                 WET|                3|         11|                  6|
# |             2015-11-18|           ACCESS ST|            CLEAR|            DAYLIGHT|             UNKNOWN|                4|         11|                  1|
# |             2015-11-25|       MILWAUKEE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|         11|                  2|
# |             2015-12-04|         WESTERN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|         12|                  5|
# |             2015-12-31|         AUSTIN BLVD|            CLEAR|            DAYLIGHT|                 DRY|                5|         12|                  3|
# |             2016-01-03|   INDEPENDENCE BLVD|            CLEAR|            DAYLIGHT|                 DRY|                1|          1|                  1|
# |             2016-01-04|           ESSEX AVE|             SNOW|             UNKNOWN|                 WET|                2|          1|                  1|
# |             2016-01-11|         WESTERN AVE|             SNOW|            DAYLIGHT|       SNOW OR SLUSH|                2|          1|                  2|
# |             2016-01-23|          EUCLID AVE|            CLEAR|                DAWN|       SNOW OR SLUSH|                7|          1|                  1|
# |             2016-01-24|           GRAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          1|                  2|
# |             2016-01-27|           MONROE ST|          UNKNOWN|            DARKNESS|                 DRY|                4|          1|                  1|
# |             2016-01-31|          PULASKI RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          1|                  3|
# |             2016-02-19|         PERSHING RD|          UNKNOWN|            DARKNESS|             UNKNOWN|                6|          2|                  1|
# |             2016-02-19|     WASHINGTON BLVD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          2|                  1|
# |             2016-02-22|        ARMITAGE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          2|                  1|
# |             2016-03-02|         HARRISON ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          3|                  1|
# |             2016-03-15|         LANGLEY AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          3|                  1|
# |             2016-03-18|        LAWNDALE AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          3|                  2|
# |             2016-03-20|         LARAMIE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          3|                  1|
# |             2016-03-24|          CICERO AVE|             RAIN|            DARKNESS|                 WET|                5|          3|                  1|
# |             2016-03-25|         BELMONT AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                6|          3|                  2|
# |             2016-04-05|DR MARTIN LUTHER ...|            CLEAR|            DAYLIGHT|                 DRY|                3|          4|                  1|
# |             2016-04-07|         ASHLAND AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                5|          4|                  1|
# |             2016-04-07|         RANDOLPH ST|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                5|          4|                  1|
# |             2016-04-09|          WABASH AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          4|                  2|
# |             2016-04-13|          HARLEM AVE|            CLEAR|                DUSK|                 DRY|                4|          4|                  2|
# |             2016-04-17|         HARRISON ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          4|                  1|
# |             2016-04-26|         SUPERIOR ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          4|                  1|
# |             2016-05-01|      NORTH PARK AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          5|                  1|
# |             2016-05-10|           BARRY AVE|            CLEAR|                DAWN|                 DRY|                3|          5|                  2|
# |             2016-05-10|           NORTH AVE|             RAIN|            DAYLIGHT|                 WET|                3|          5|                  1|
# |             2016-05-13|       CONGRESS PKWY|            CLEAR|            DAYLIGHT|                 DRY|                6|          5|                  1|
# |             2016-05-20|            ADAMS ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          5|                  2|
# |             2016-05-21|           DANTE AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          5|                  1|
# |             2016-05-23|             59TH ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          5|                  1|
# |             2016-05-30|            ADAMS ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          5|                  1|
# |             2016-05-31|         LARRABEE ST|             RAIN|            DAYLIGHT|                 WET|                3|          5|                  2|
# |             2016-06-10|           THROOP ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          6|                  1|
# |             2016-06-13|        LEXINGTON ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          6|                  1|
# |             2016-06-20|        TRUMBULL AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          6|                  1|
# |             2016-07-02|   SOUTH CHICAGO AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          7|                  1|
# |             2016-07-09|       GRANVILLE AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          7|                  1|
# |             2016-07-10|DR MARTIN LUTHER ...|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          7|                  2|
# |             2016-07-16|             68TH PL|            CLEAR|            DAYLIGHT|                 DRY|                7|          7|                  1|
# |             2016-07-20|         BEVERLY AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                4|          7|                  1|
# |             2016-07-23|        MARQUETTE RD|             RAIN|DARKNESS, LIGHTED...|                 WET|                7|          7|                  3|
# |             2016-07-24|       LAKE SHORE DR|            CLEAR|            DAYLIGHT|                 DRY|                1|          7|                  2|
# |             2016-07-25|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          7|                  7|
# |             2016-07-27|    STONY ISLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  2|
# |             2016-07-28|             89TH ST|            CLEAR|            DARKNESS|                 DRY|                5|          7|                  1|
# |             2016-07-28|      IRVING PARK RD|             RAIN|            DAYLIGHT|                 DRY|                5|          7|                  1|
# |             2016-07-31|            WELLS ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          7|                  2|
# |             2016-08-07|         LOOMIS BLVD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  2|
# |             2016-08-17|        DOUGLAS BLVD|            CLEAR|                DUSK|                 DRY|                4|          8|                  1|
# |             2016-08-19|            HURON ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|
# |             2016-08-22|             47TH ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|
# |             2016-08-26|       CHARLESTON ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|
# |             2016-08-28|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  8|
# |             2016-08-29|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|
# |             2016-08-29|         DELAWARE PL|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|
# |             2016-09-04|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  7|
# |             2016-09-05|         LARAMIE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  2|
# |             2016-09-06|             47TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  3|
# |             2016-09-07|             71ST ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  3|
# |             2016-09-09|       SHEFFIELD AVE|            CLEAR|            DARKNESS|                 DRY|                6|          9|                  1|
# |             2016-09-10|          CICERO AVE|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                7|          9|                  6|
# |             2016-09-11|         PERSHING RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          9|                  1|
# |             2016-09-15|          RIDGE BLVD|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|
# |             2016-09-15|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  4|
# |             2016-09-30|         HAMLIN BLVD|            CLEAR|            DAYLIGHT|                 WET|                6|          9|                  1|
# |             2016-09-30|         PERSHING RD|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                6|          9|                  1|
# |             2016-10-01|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|         10|                  7|
# |             2016-10-07|          TALMAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         10|                  1|
# |             2016-10-09|   CHICAGO SKYWAY OB|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|         10|                  1|
# |             2016-10-13|          ARCHER AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         10|                  2|
# |             2016-10-16|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|         10|                  5|
# |             2016-10-23|             ERIE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|         10|                  1|
# |             2016-10-23|        LAWNDALE AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|         10|                  1|
# |             2016-10-28|   BESSIE COLEMAN DR|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                6|         10|                  1|
# |             2016-10-29|             LAKE ST|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                7|         10|                  2|
# |             2016-10-31|       CONGRESS PKWY|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|         10|                  2|
# |             2016-11-02|    LAKE SHORE DR NB|             RAIN|                DUSK|                 WET|                4|         11|                  2|
# |             2016-11-05|          JEFFERY DR|            CLEAR|            DAYLIGHT|                 DRY|                7|         11|                  1|
# |             2016-11-07|             60TH PL|            CLEAR|            DAYLIGHT|                 DRY|                2|         11|                  1|
# |             2016-11-08|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|         11|                  3|
# |             2016-11-10|             87TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|         11|                  3|
# |             2016-11-11|             35TH ST|            CLEAR|            DAYLIGHT|                 DRY|                6|         11|                  1|
# |             2016-11-12|       FULLERTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|         11|                  3|
# |             2016-11-14|         ABERDEEN ST|            CLEAR|            DARKNESS|                 DRY|                2|         11|                  1|
# |             2016-11-16|          HALSTED ST|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                4|         11|                  4|
# |             2016-11-18|    STONY ISLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         11|                  5|
# |             2016-11-29|          STATE PKWY|            CLEAR|            DAYLIGHT|                 DRY|                3|         11|                  1|
# |             2016-12-01|     ST LAWRENCE AVE|            CLEAR|            DARKNESS|                 DRY|                5|         12|                  1|
# |             2016-12-06|             59TH ST|          UNKNOWN|            DAYLIGHT|                 DRY|                3|         12|                  1|
# |             2016-12-13|DR MARTIN LUTHER ...|            CLEAR|            DARKNESS|                 DRY|                3|         12|                  5|
# |             2016-12-18|           KINZIE ST|  CLOUDY/OVERCAST|             UNKNOWN|                 WET|                1|         12|                  1|
# |             2016-12-20|            STATE ST|            CLEAR|            DAYLIGHT|                 DRY|                3|         12|                 10|
# |             2016-12-23|           TOUHY AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         12|                  2|
# |             2016-12-30|         OAKLEY BLVD|            CLEAR|            DAYLIGHT|                 DRY|                6|         12|                  1|
# |             2017-01-01|      COAST GUARD DR|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          1|                  1|
# |             2017-01-02|         LINCOLN AVE|             RAIN|            DARKNESS|                 WET|                2|          1|                  1|
# |             2017-01-05|             79TH ST|            CLEAR|            DARKNESS|                 DRY|                5|          1|                  1|
# |             2017-01-05|         KIMBALL AVE|          UNKNOWN|             UNKNOWN|                 DRY|                5|          1|                  1|
# |             2017-01-08|       GARFIELD BLVD|            CLEAR|            DARKNESS|                 DRY|                1|          1|                  1|
# |             2017-01-08|           HOWARD ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          1|                  1|
# |             2017-01-10|        ARTESIAN AVE|             RAIN|            DAYLIGHT|                 WET|                3|          1|                  1|
# |             2017-01-11|    LAKE SHORE DR NB|             RAIN|            DARKNESS|                 WET|                4|          1|                  3|
# |             2017-01-13|          SAWYER AVE|          UNKNOWN|            DARKNESS|             UNKNOWN|                6|          1|                  1|
# |             2017-01-14|             70TH ST|            CLEAR|DARKNESS, LIGHTED...|                 ICE|                7|          1|                  1|
# |             2017-01-15|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          1|                  4|
# |             2017-01-19|          ONTARIO ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          1|                  2|
# |             2017-01-25|           MORGAN ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          1|                  1|
# |             2017-02-01|       LAKE SHORE DR|            CLEAR|            DAYLIGHT|                 DRY|                4|          2|                  2|
# |             2017-02-02|        PROSPECT AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          2|                  2|
# |             2017-02-03|             63RD ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          2|                  3|
# |             2017-02-03|         BELMONT AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          2|                  2|
# |             2017-02-07|          HALSTED ST|             RAIN|            DAYLIGHT|                 WET|                3|          2|                  2|
# |             2017-02-11|            BROADWAY|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          2|                  5|
# |             2017-02-12|             53RD ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          2|                  1|
# |             2017-02-13|          CICERO AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          2|                  6|
# |             2017-02-17|           PALMER ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          2|                  1|
# |             2017-02-21|             47TH ST|             RAIN|            DARKNESS|                 WET|                3|          2|                  2|
# |             2017-02-21|        MONTROSE AVE|            CLEAR|            DARKNESS|                 DRY|                3|          2|                  2|
# |             2017-02-22|         ASHLAND AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 WET|                4|          2|                  4|
# |             2017-02-23|          MADISON ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          2|                  3|
# |             2017-02-24|             79TH ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          2|                  3|
# |             2017-03-08|         PALMER BLVD|            CLEAR|            DAYLIGHT|                 DRY|                4|          3|                  1|
# |             2017-03-12|         CHICAGO AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          3|                  2|
# |             2017-03-13|            BROADWAY|             SNOW|            DAYLIGHT|       SNOW OR SLUSH|                2|          3|                  2|
# |             2017-03-14|          WABASH AVE|  CLOUDY/OVERCAST|                DUSK|                 WET|                3|          3|                  2|
# |             2017-03-18|   CHICAGO SKYWAY IB|            CLEAR|            DARKNESS|                 WET|                7|          3|                  2|
# |             2017-03-22|          PULASKI RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          3|                  3|
# |             2017-03-24|             63RD ST|             RAIN|            DARKNESS|                 WET|                6|          3|                  2|
# |             2017-03-25|        WILDWOOD AVE|            CLEAR|            DAYLIGHT|                 WET|                7|          3|                  1|
# |             2017-04-04|          WARNER AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          4|                  1|
# |             2017-04-05|           TAYLOR ST|             RAIN|            DARKNESS|                 WET|                4|          4|                  1|
# |             2017-04-06|       GARFIELD BLVD|            CLEAR|            DAYLIGHT|                 DRY|                5|          4|                  2|
# |             2017-04-07|    MUSEUM CAMPUS DR|            CLEAR|            DAYLIGHT|                 DRY|                6|          4|                  1|
# |             2017-04-14|       GARFIELD BLVD|            CLEAR|            DAYLIGHT|                 DRY|                6|          4|                  3|
# |             2017-04-17|          CICERO AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          4|                  8|
# |             2017-04-18|            107TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          4|                  1|
# |             2017-04-23|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          4|                  4|
# |             2017-04-24|           MONROE ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          4|                  1|
# |             2017-04-25|             73RD ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          4|                  1|
# |             2017-04-25|         CHICAGO AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          4|                  3|
# |             2017-04-25|       LAKE SHORE DR|            CLEAR|            DAYLIGHT|             UNKNOWN|                3|          4|                  1|
# |             2017-04-26|            BELL AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          4|                  1|
# |             2017-04-28|         COLUMBUS DR|            CLEAR|            DAYLIGHT|                 DRY|                6|          4|                  2|
# |             2017-04-30|        MARQUETTE RD|             RAIN|DARKNESS, LIGHTED...|                 WET|                1|          4|                  4|
# |             2017-05-02|       BRYN MAWR AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          5|                  1|
# |             2017-05-09|        AUGUSTA BLVD|            CLEAR|            DAYLIGHT|                 DRY|                3|          5|                  3|
# |             2017-05-14|      MARSHFIELD AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          5|                  1|
# |             2017-05-15|           SAYRE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          5|                  1|
# |             2017-05-15|          WILSON AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          5|                  1|
# |             2017-05-21|             70TH ST|             RAIN|            DAYLIGHT|                 WET|                1|          5|                  1|
# |             2017-05-29|         EMERALD AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          5|                  2|
# |             2017-05-29|        TRUMBULL AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          5|                  1|
# |             2017-05-31|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                4|          5|                  2|
# |             2017-06-01|         OAKDALE AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          6|                  1|
# |             2017-06-02|         CATALPA AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          6|                  2|
# |             2017-06-05|          CICERO AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          6|                 11|
# |             2017-06-06|    STONY ISLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          6|                  3|
# |             2017-06-08|          HALSTED ST|            CLEAR|                DUSK|                 DRY|                5|          6|                  7|
# |             2017-06-08|        MONTROSE AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          6|                  1|
# |             2017-06-09|          PULASKI RD|            CLEAR|                DUSK|                 DRY|                6|          6|                  4|
# |             2017-06-19|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          6|                  7|
# |             2017-06-19|        KILBOURN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          6|                  1|
# |             2017-06-19|     WASHINGTON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                2|          6|                  1|
# |             2017-06-21|          WALLER AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          6|                  1|
# |             2017-06-22|          COLFAX AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          6|                  1|
# |             2017-06-22|        KINGSBURY ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          6|                  1|
# |             2017-06-27|         CENTRAL AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          6|                  3|
# |             2017-06-28|      COMMERCIAL AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          6|                  1|
# |             2017-06-28|         DIVISION ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          6|                  2|
# |             2017-06-28|         LOOMIS BLVD|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                4|          6|                  2|
# |             2017-06-28|        WESTERN BLVD|             RAIN|            DAYLIGHT|                 WET|                4|          6|                  1|
# |             2017-06-30|          HALSTED ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          6|                  7|
# |             2017-07-02|         FLOURNOY ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          7|                  1|
# |             2017-07-09|         CHICAGO AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          7|                  1|
# |             2017-07-10|     LAKE SHORE DR E|             RAIN|            DAYLIGHT|                 WET|                2|          7|                  1|
# |             2017-07-11|       SOUTHPORT AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          7|                  1|
# |             2017-07-12|           GRAND AVE|             RAIN|            DARKNESS|                 WET|                4|          7|                  4|
# |             2017-07-17|       WENTWORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          7|                  2|
# |             2017-07-18|      WRIGHTWOOD AVE|            CLEAR|            DARKNESS|                 DRY|                3|          7|                  1|
# |             2017-07-20|        CAMPBELL AVE|            OTHER|            DAYLIGHT|                 WET|                5|          7|                  2|
# |             2017-07-22|    LAKE SHORE DR SB|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          7|                  3|
# |             2017-07-23|     LAKE SHORE DR W|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          7|                  2|
# |             2017-07-23| LITHUANIAN PLAZA CT|            CLEAR|            DAYLIGHT|                 DRY|                1|          7|                  1|
# |             2017-07-24|          YATES BLVD|            CLEAR|            DAYLIGHT|                 DRY|                2|          7|                  1|
# |             2017-07-25|             83RD ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          7|                  2|
# |             2017-07-25|         CHESTNUT ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          7|                  1|
# |             2017-07-26|           ELLIS AVE|            CLEAR|                DAWN|                 DRY|                4|          7|                  1|
# |             2017-07-26|         KIMBALL AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  2|
# |             2017-07-29|             14TH PL|            CLEAR|            DAYLIGHT|                 DRY|                7|          7|                  1|
# |             2017-08-16|          ADDISON ST|             RAIN|DARKNESS, LIGHTED...|                 WET|                4|          8|                  6|
# |             2017-08-18|            CLARK ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  7|
# |             2017-08-22|         CHICAGO AVE|             RAIN|            DAYLIGHT|                 WET|                3|          8|                  1|
# |             2017-08-23|      RAVENSWOOD AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|
# |             2017-08-30|           UNION AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  2|
# |             2017-09-05|         CALUMET AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  2|
# |             2017-09-05|         PERSHING RD|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|
# |             2017-09-06|            CLARK ST|             RAIN|            DAYLIGHT|                 WET|                4|          9|                  5|
# |             2017-09-08|       FULLERTON AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          9|                  4|
# |             2017-09-08|          PAULINA ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  1|
# |             2017-09-08|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  4|
# |             2017-09-14|DR MARTIN LUTHER ...|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  2|
# |             2017-09-17|             62ND ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  1|
# |             2017-09-17|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  7|
# |             2017-09-18|       WASHTENAW AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|
# |             2017-09-20|           DAMEN AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|
# |             2017-09-21|         MC LEAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|
# |             2017-09-21|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  4|
# |             2017-09-22|            GREEN ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  1|
# |             2017-09-22|         LARAMIE AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  6|
# |             2017-09-24|       FULLERTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  3|
# |             2017-09-26|           OGDEN AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  5|
# |             2017-09-28|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  4|
# |             2017-09-30|          LOGAN BLVD|            CLEAR|            DAYLIGHT|                 DRY|                7|          9|                  1|
# |             2017-10-01|             95TH ST|            CLEAR|            DAYLIGHT|                 DRY|                1|         10|                  2|
# |             2017-10-01|        JACKSON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                1|         10|                  2|
# |             2017-10-03|          HALSTED ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|         10|                 12|
# |             2017-10-03|   INDEPENDENCE BLVD|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                3|         10|                  1|
# |             2017-10-04|           KOLIN AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|         10|                  1|
# |             2017-10-06|             31ST ST|            CLEAR|             UNKNOWN|                 DRY|                6|         10|                  1|
# |             2017-10-06|        JEFFERSON ST|             RAIN|            DAYLIGHT|                 WET|                6|         10|                  1|
# |             2017-10-07|             79TH ST|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                7|         10|                  3|
# |             2017-10-08|             44TH ST|            CLEAR|             UNKNOWN|                 DRY|                1|         10|                  2|
# |             2017-10-11|          FOSTER AVE|             RAIN|            DAYLIGHT|                 WET|                4|         10|                  4|
# |             2017-10-12|      CALIFORNIA AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|         10|                 10|
# |             2017-10-13|   CHICAGO SKYWAY OB|            CLEAR|            DAYLIGHT|                 DRY|                6|         10|                  1|
# |             2017-10-14|       MILWAUKEE AVE|             RAIN|DARKNESS, LIGHTED...|                 WET|                7|         10|                  4|
# |             2017-10-18|           PALMER ST|            CLEAR|            DAYLIGHT|                 DRY|                4|         10|                  2|
# |             2017-10-21|            103RD ST|            CLEAR|                DUSK|                 DRY|                7|         10|                  1|
# |             2017-10-24|       LAKE SHORE DR|             RAIN|            DAYLIGHT|                 WET|                3|         10|                 10|
# |             2017-10-26|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|         10|                  6|
# |             2017-10-26|           HOMAN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         10|                  1|
# |             2017-10-26|        VAN BUREN ST|            CLEAR|            DARKNESS|                 DRY|                5|         10|                  1|
# |             2017-10-28|             16TH ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|         10|                  1|
# |             2017-10-29|       FULLERTON AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|         10|                  6|
# |             2017-10-31|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|         10|                  3|
# |             2017-11-01|         RANDOLPH ST|            CLEAR|            DARKNESS|                 DRY|                4|         11|                  4|
# |             2017-11-02|         CENTRAL AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 WET|                5|         11|                  6|
# |             2017-11-04|             71ST ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|         11|                  3|
# |             2017-11-04|         CENTRAL AVE|             RAIN|            DAYLIGHT|                 WET|                7|         11|                  2|
# |             2017-11-04|         EMERALD AVE|             RAIN|            DAYLIGHT|                 WET|                7|         11|                  1|
# |             2017-11-04|             SURF ST|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                7|         11|                  1|
# |             2017-11-06|   CHICAGO SKYWAY OB|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                2|         11|                  1|
# |             2017-11-08|             57TH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|         11|                  2|
# |             2017-11-08|          FOSTER AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|         11|                  3|
# |             2017-11-08|          KEDZIE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|         11|                  4|
# |             2017-11-10|          ADDISON ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|         11|                  3|
# |             2017-11-10|           GRAND AVE|             SNOW|            DAYLIGHT|                 WET|                6|         11|                  9|
# |             2017-11-13|           MARINE DR|            CLEAR|            DAYLIGHT|                 WET|                2|         11|                  1|
# |             2017-11-17|          ARCHER AVE|             RAIN|            DARKNESS|                 WET|                6|         11|                  6|
# |             2017-11-18|         KOSTNER AVE|             RAIN|            DAYLIGHT|                 WET|                7|         11|                  4|
# |             2017-11-18|         WESTERN AVE|            CLEAR|DARKNESS, LIGHTED...|                 WET|                7|         11|                  7|
# |             2017-11-21|             92ND ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|         11|                  1|
# |             2017-11-22|            115TH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|         11|                  1|
# |             2017-11-24|         ASHLAND AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|         11|                  3|
# |             2017-11-24|        ROOSEVELT RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|         11|                  2|
# |             2017-11-25|         CENTRAL AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|         11|                  3|
# |             2017-11-27|             43RD ST|            CLEAR|            DAYLIGHT|                 DRY|                2|         11|                  1|
# |             2017-12-01|            103RD ST|            CLEAR|            DAYLIGHT|                 DRY|                6|         12|                  4|
# |             2017-12-01|    NARRAGANSETT AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         12|                  2|
# |             2017-12-07|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                5|         12|                  3|
# |             2017-12-07|            STATE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         12|                  7|
# |             2017-12-08|          MADISON ST|          UNKNOWN|             UNKNOWN|       SNOW OR SLUSH|                6|         12|                  3|
# |             2017-12-10|           BARRY AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|         12|                  1|
# |             2017-12-10|     LAKE SHORE DR E|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|         12|                  1|
# |             2017-12-11|    NARRAGANSETT AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                2|         12|                  2|
# |             2017-12-12|          ARCHER AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|         12|                  5|
# |             2017-12-15|             66TH ST|            CLEAR|            DAYLIGHT|                 DRY|                6|         12|                  1|
# |             2017-12-17|         LE MOYNE ST|            CLEAR|            DAYLIGHT|                 DRY|                1|         12|                  4|
# |             2017-12-19|             79TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|         12|                  1|
# |             2017-12-20|         WESTERN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|         12|                 10|
# |             2017-12-21|        ARMITAGE AVE|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                5|         12|                  2|
# |             2017-12-21|      IRVING PARK RD|            CLEAR|            DAYLIGHT|                 DRY|                5|         12|                  6|
# |             2017-12-21|         KIMBALL AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         12|                  3|
# |             2017-12-21|         WESTERN AVE|            CLEAR|            DARKNESS|                 DRY|                5|         12|                 16|
# |             2017-12-28|       SPAULDING AVE|            CLEAR|                DAWN|       SNOW OR SLUSH|                5|         12|                  1|
# |             2017-12-29|          KEDZIE AVE|             SNOW|            DAYLIGHT|       SNOW OR SLUSH|                6|         12|                 14|
# |             2017-12-30|           HOWARD ST|            CLEAR|            DAYLIGHT|                 WET|                7|         12|                  2|
# |             2017-12-30|    STONY ISLAND AVE|  CLOUDY/OVERCAST|            DAYLIGHT|       SNOW OR SLUSH|                7|         12|                  7|
# |             2017-12-31|             21ST ST|            CLEAR|DARKNESS, LIGHTED...|                 WET|                1|         12|                  1|
# |             2017-12-31|             ERIE ST|            CLEAR|             UNKNOWN|                 DRY|                1|         12|                  1|
# |             2017-12-31|       RIDGELAND AVE|            CLEAR|DARKNESS, LIGHTED...|       SNOW OR SLUSH|                1|         12|                  1|
# ...
# |             2020-07-14|           COLES AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          7|                  1|
# |             2020-07-15|        ESCANABA AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  1|
# |             2020-07-15|          HALSTED ST|             RAIN|                DAWN|                 WET|                4|          7|                  6|
# |             2020-07-17|             87TH ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          7|                  3|
# |             2020-07-18|          HALSTED ST|            CLEAR|            DAYLIGHT|             UNKNOWN|                7|          7|                  4|
# |             2020-07-18|       HUMBOLDT BLVD|            CLEAR|             UNKNOWN|             UNKNOWN|                7|          7|                  2|
# |             2020-07-22|             47TH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  5|
# |             2020-07-22|       WENTWORTH AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          7|                  4|
# |             2020-07-24|          RACINE AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          7|                  4|
# |             2020-07-25|         LE MOYNE ST|          UNKNOWN|             UNKNOWN|             UNKNOWN|                7|          7|                  1|
# |             2020-07-26|             63RD ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          7|                  1|
# |             2020-07-26|           MORGAN ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          7|                  3|
# |             2020-07-27|             59TH ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          7|                  1|
# |             2020-07-27|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          7|                  1|
# |             2020-07-29|          FOSTER AVE|             RAIN|            DAYLIGHT|                 WET|                4|          7|                  4|
# |             2020-07-29|           GRAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  4|
# |             2020-07-30|         HIGGINS AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          7|                  2|
# |             2020-07-31|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          7|                  9|
# |             2020-08-04|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  3|
# |             2020-08-04|         CHICAGO AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          8|                  2|
# |             2020-08-04|POPE JOHN PAUL II DR|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|
# |             2020-08-06|          PULASKI RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          8|                  7|
# |             2020-08-07|         ASHLAND AVE|            CLEAR|            DARKNESS|                 DRY|                6|          8|                  7|
# |             2020-08-07|     WASHINGTON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  3|
# |             2020-08-09|             76TH ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  2|
# |             2020-08-12|             29TH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|
# |             2020-08-15|           DEVON AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  3|
# |             2020-08-16|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  5|
# |             2020-08-17|             WOOD ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|
# |             2020-08-24|             67TH ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|
# |             2020-08-25|           MORGAN ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  2|
# |             2020-08-27|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  9|
# |             2020-08-28|      IRVING PARK RD|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  3|
# |             2020-08-29|             64TH ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|
# |             2020-08-30|          FOSTER AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|
# |             2020-08-31|       MILWAUKEE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  3|
# |             2020-09-04|          PULASKI RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          9|                 12|
# |             2020-09-06|            COUCH PL|            CLEAR|            DARKNESS|                 DRY|                1|          9|                  1|
# |             2020-09-06|           PEORIA ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  2|
# |             2020-09-08|          WABASH AVE|             RAIN|            DAYLIGHT|                 WET|                3|          9|                  2|
# |             2020-09-11|             LAKE ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  2|
# |             2020-09-11|            OHARE ST|            CLEAR|DARKNESS, LIGHTED...|                 WET|                6|          9|                  2|
# |             2020-09-11|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                 10|
# |             2020-09-11|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  7|
# |             2020-09-17|         WEBSTER AVE|            CLEAR|            DARKNESS|                 DRY|                5|          9|                  1|
# |             2020-09-18|    CENTRAL PARK AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  4|
# |             2020-09-18|           HOMAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          9|                  1|
# |             2020-09-20|         HARRISON ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  2|
# |             2020-09-22|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                 11|
# |             2020-09-23|       WENTWORTH AVE|            CLEAR|                DUSK|                 DRY|                4|          9|                  4|
# |             2020-09-25|             18TH ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          9|                  2|
# |             2020-09-27|             47TH ST|            CLEAR|            DARKNESS|                 DRY|                1|          9|                  3|
# |             2020-09-29|        MONTROSE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|
# |             2020-09-29|       SPAULDING AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|
# |             2020-09-30|        JACKSON BLVD|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                4|          9|                  1|
# |             2020-10-02|          KARLOV AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         10|                  3|
# |             2020-10-02|    LAKE SHORE DR NB|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|         10|                  5|
# |             2020-10-05|          KEELER AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|         10|                  1|
# |             2020-10-06|    CENTRAL PARK AVE|            CLEAR|            DARKNESS|                 DRY|                3|         10|                  4|
# |             2020-10-07|          KOLMAR AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|         10|                  1|
# |             2020-10-08|            OHARE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         10|                  1|
# |             2020-10-09|           BARRY AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         10|                  2|
# |             2020-10-18|             89TH ST|             RAIN|            DAYLIGHT|                 WET|                1|         10|                  1|
# |             2020-10-18|            GREEN ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|         10|                  2|
# |             2020-10-25|             85TH ST|            CLEAR|            DARKNESS|                 DRY|                1|         10|                  1|
# |             2020-10-28|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|         10|                  2|
# |             2020-10-31|             37TH ST|          UNKNOWN|            DARKNESS|             UNKNOWN|                7|         10|                  1|
# |             2020-10-31|          KEDZIE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|         10|                  3|
# |             2020-11-09|             65TH ST|            CLEAR|            DAYLIGHT|                 DRY|                2|         11|                  1|
# |             2020-11-09|          HARLEM AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|         11|                  2|
# |             2020-11-11|           NAGLE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|         11|                  1|
# |             2020-11-12|            YALE AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|         11|                  2|
# |             2020-11-13|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         11|                  2|
# |             2020-11-14|            111TH ST|            CLEAR|            DAYLIGHT|                 DRY|                7|         11|                  1|
# |             2020-11-14|        AUGUSTA BLVD|            CLEAR|                DAWN|                 DRY|                7|         11|                  3|
# |             2020-11-15|       THORNDALE AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                1|         11|                  1|
# |             2020-11-21|         CHICAGO AVE|             SNOW|            DAYLIGHT|                 DRY|                7|         11|                  1|
# |             2020-11-21|          RHODES AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|         11|                  1|
# |             2020-11-22|       FRANCISCO AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|         11|                  1|
# |             2020-11-22|    LAKE SHORE DR SB|             RAIN|            DAYLIGHT|                 WET|                1|         11|                  3|
# |             2020-11-23|         HARRISON ST|            CLEAR|            DAYLIGHT|                 DRY|                2|         11|                  1|
# |             2020-11-26|        ROOSEVELT RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         11|                  2|
# |             2020-11-27|        EBERHART AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|         11|                  1|
# |             2020-12-01|             56TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|         12|                  1|
# |             2020-12-04|         BELMONT AVE|            CLEAR|                DUSK|                 DRY|                6|         12|                  5|
# |             2020-12-05|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|         12|                  1|
# |             2020-12-06|             79TH ST|            CLEAR|            DAYLIGHT|                 DRY|                1|         12|                  3|
# |             2020-12-07|        JEFFERY BLVD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|         12|                  1|
# |             2020-12-12|          HAMLIN AVE|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                7|         12|                  2|
# |             2020-12-17|        PHILLIPS AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|         12|                  1|
# |             2020-12-20|          ARTHUR AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|         12|                  1|
# |             2020-12-22|           OGDEN AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|         12|                  3|
# |             2020-12-24|        ROOSEVELT RD|            CLEAR|DARKNESS, LIGHTED...|                 ICE|                5|         12|                  4|
# |             2020-12-26|             87TH ST|            CLEAR|            DAYLIGHT|                 DRY|                7|         12|                  2|
# |             2020-12-26|          ALBANY AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|         12|                  1|
# |             2020-12-31|             16TH ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|         12|                  2|
# |             2020-12-31|           NORTH AVE|            CLEAR|            DAYLIGHT|                 WET|                5|         12|                  2|
# |             2021-01-02|        WEST END AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 WET|                7|          1|                  1|
# |             2021-01-07|       BRYN MAWR AVE|          UNKNOWN|                DUSK|             UNKNOWN|                5|          1|                  2|
# |             2021-01-07|          RACINE AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          1|                  1|
# +-----------------------+--------------------+-----------------+--------------------+--------------------+-----------------+-----------+-------------------+
# only showing top 1000 rows

# %%
# dropping null records
final_df = final_df.dropna()

# Convert 'NUMBER_OF_ACCIDENTS' column from 'long' to 'integer'
final_df = final_df.withColumn("NUMBER_OF_ACCIDENTS", final_df["NUMBER_OF_ACCIDENTS"].cast(IntegerType()))

final_df.printSchema()
# Out:
# root
#  |-- CRASH_DATE_STANDARDIZED: date (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#  |-- WEATHER_CONDITION: string (nullable = true)
#  |-- LIGHTING_CONDITION: string (nullable = true)
#  |-- ROADWAY_SURFACE_COND: string (nullable = true)
#  |-- CRASH_DAY_OF_WEEK: integer (nullable = true)
#  |-- CRASH_MONTH: integer (nullable = true)
#  |-- NUMBER_OF_ACCIDENTS: integer (nullable = true)

# %%
# Group the final_df by 'NUMBER_OF_ACCIDENTS' and count the number of records for each value
count_by_accidents = final_df.groupBy('NUMBER_OF_ACCIDENTS').count()


# Order the count_by_accidents DataFrame by the 'NUMBER_OF_ACCIDENTS' column in ascending order
count_by_accidents_ordered = count_by_accidents.orderBy('NUMBER_OF_ACCIDENTS')

# Show the count for each value of 'NUMBER_OF_ACCIDENTS' in ascending order
count_by_accidents_ordered.show(1000)
# Out:
# +-------------------+------+
# |NUMBER_OF_ACCIDENTS| count|
# +-------------------+------+
# |                  1|310021|
# |                  2|164010|
# |                  3|104724|
# |                  4| 71068|
# |                  5| 48550|
# |                  6| 34224|
# |                  7| 24199|
# |                  8| 18832|
# |                  9| 13221|
# |                 10| 10630|
# |                 11|  7029|
# |                 12|  4860|
# |                 13|  3341|
# |                 14|  2478|
# |                 15|  1485|
# |                 16|   960|
# |                 17|   442|
# |                 18|   252|
# |                 19|   114|
# |                 20|    60|
# |                 21|    42|
# |                 22|    44|
# +-------------------+------+

# %%
# Add a new column 'SAFE' based on the value of 'NUMBER_OF_ACCIDENTS'
final_df = final_df.withColumn("SAFE", when(final_df["NUMBER_OF_ACCIDENTS"] >= 3, 0).otherwise(1))

final_df.printSchema()
# Out:
# root
#  |-- CRASH_DATE_STANDARDIZED: date (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#  |-- WEATHER_CONDITION: string (nullable = true)
#  |-- LIGHTING_CONDITION: string (nullable = true)
#  |-- ROADWAY_SURFACE_COND: string (nullable = true)
#  |-- CRASH_DAY_OF_WEEK: integer (nullable = true)
#  |-- CRASH_MONTH: integer (nullable = true)
#  |-- NUMBER_OF_ACCIDENTS: integer (nullable = true)
#  |-- SAFE: integer (nullable = false)

# %%
# Show the updated DataFrame
final_df.show(1000)
# Out:
# +-----------------------+--------------------+-----------------+--------------------+--------------------+-----------------+-----------+-------------------+----+
# |CRASH_DATE_STANDARDIZED|         STREET_NAME|WEATHER_CONDITION|  LIGHTING_CONDITION|ROADWAY_SURFACE_COND|CRASH_DAY_OF_WEEK|CRASH_MONTH|NUMBER_OF_ACCIDENTS|SAFE|
# +-----------------------+--------------------+-----------------+--------------------+--------------------+-----------------+-----------+-------------------+----+
# |             2014-01-18|             LAKE ST|            CLEAR|                DUSK|                 DRY|                7|          1|                  1|   1|
# |             2014-11-11|           DEVON AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                3|         11|                  1|   1|
# |             2015-04-06|         ASHLAND AVE|            CLEAR|            DARKNESS|                 DRY|                2|          4|                  1|   1|
# |             2015-04-15|          PULASKI RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          4|                  1|   1|
# |             2015-04-16|DR MARTIN LUTHER ...|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          4|                  1|   1|
# |             2015-05-15| FOREST PRESERVE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          5|                  1|   1|
# |             2015-05-20|       SPAULDING AVE|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                4|          5|                  1|   1|
# |             2015-05-25|          CICERO AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          5|                  1|   1|
# |             2015-06-22|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          6|                  1|   1|
# |             2015-07-02|        ANN LURIE PL|            CLEAR|            DAYLIGHT|                 DRY|                5|          7|                  1|   1|
# |             2015-07-07|       GARFIELD BLVD|            CLEAR|            DAYLIGHT|                 DRY|                3|          7|                  1|   1|
# |             2015-07-18|          PAULINA ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          7|                  1|   1|
# |             2015-07-22|            STATE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          7|                  1|   1|
# |             2015-07-25|          HAMLIN AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          7|                  1|   1|
# |             2015-07-28|        MONTROSE AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          7|                  1|   1|
# |             2015-07-29|            111TH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  1|   1|
# |             2015-07-29|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          7|                  1|   1|
# |             2015-07-31|             24TH PL|            CLEAR|            DAYLIGHT|                 DRY|                6|          7|                  1|   1|
# |             2015-07-31|        CARPENTER ST|          UNKNOWN|             UNKNOWN|             UNKNOWN|                6|          7|                  1|   1|
# |             2015-08-02|           NORTH AVE|            CLEAR|                DUSK|                 DRY|                1|          8|                  1|   1|
# |             2015-08-03|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-03|       MILWAUKEE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-04|           LOTUS AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-04|        MAYFIELD AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          8|                  1|   1|
# |             2015-08-05|       CONGRESS PKWY|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-05|          KEDZIE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-05|      MARSHFIELD AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-05|             RUSH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-06|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-06|      LEAMINGTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-06|            STATE ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-07|         CHICAGO AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          8|                  1|   1|
# |             2015-08-07|           FULTON ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-07|          ORLEANS ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-07|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-07|             RUSH ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-07|          WALLER AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-08|            111TH ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-08|            CANAL ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-08|           DAMEN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-08|         ILLINOIS ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-08|         MIDWAY PARK|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-09|         LATROBE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  1|   1|
# |             2015-08-09|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-09|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-09|          ONTARIO ST|            CLEAR|            DARKNESS|                 DRY|                1|          8|                  1|   1|
# |             2015-08-09|       SHEFFIELD AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-10|            ASTOR ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-10|         CENTRAL AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                2|          8|                  1|   1|
# |             2015-08-10|            CLARK ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-10|        KILBOURN AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-10|         SUPERIOR ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-11|         CHICAGO AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-11|           GRAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-11|        JACKSON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  2|   1|
# |             2015-08-11|        JACKSON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  2|   1|
# |             2015-08-11|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-11|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-11|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-12|         DEARBORN ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-12|       FULLERTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-12|        MICHIGAN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          8|                  1|   1|
# |             2015-08-12|           NORTH AVE|            CLEAR|            DARKNESS|                 DRY|                4|          8|                  1|   1|
# |             2015-08-13|             87TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  2|   1|
# |             2015-08-13|             87TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  2|   1|
# |             2015-08-13|DR MARTIN LUTHER ...|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-13|          HUBBARD ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-13|       LAKE SHORE DR|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-14|             79TH ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-14|       DESPLAINES ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-14|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-14|        KINGSBURY ST|          UNKNOWN|             UNKNOWN|             UNKNOWN|                6|          8|                  1|   1|
# |             2015-08-14|       LAKE PARK AVE|             RAIN|DARKNESS, LIGHTED...|                 WET|                6|          8|                  1|   1|
# |             2015-08-14|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-14|    LAKE SHORE DR SB|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          8|                  2|   1|
# |             2015-08-14|        MAYFIELD AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          8|                  1|   1|
# |             2015-08-14|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-14|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-14|           OGDEN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-14|          RACINE AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-15|         DICKENS AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-15|       EGGLESTON AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-15|            HAYES DR|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-15|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  2|   1|
# |             2015-08-15|          MADISON ST|          UNKNOWN|            DARKNESS|             UNKNOWN|                7|          8|                  2|   1|
# |             2015-08-16|         DEARBORN ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-16|         KOSTNER AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  1|   1|
# |             2015-08-16|         SHERIDAN RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  1|   1|
# |             2015-08-17|         LARAMIE AVE|            CLEAR|            DAYLIGHT|             UNKNOWN|                2|          8|                  1|   1|
# |             2015-08-17|        MARQUETTE RD|          UNKNOWN|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-17|         MIDWAY PARK|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-17|           MONROE ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-17|        MONTROSE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-17|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-17|        ROOSEVELT RD|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  2|   1|
# |             2015-08-17|        ROOSEVELT RD|             RAIN|DARKNESS, LIGHTED...|                 WET|                2|          8|                  2|   1|
# |             2015-08-17|            WELLS ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-18|            111TH ST|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-18|       DIVERSEY PKWY|            CLEAR|            DARKNESS|                 DRY|                3|          8|                  1|   1|
# |             2015-08-18|           KINZIE ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-18|          ONTARIO ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-18|          WABASH AVE|          UNKNOWN|            DAYLIGHT|                 DRY|                3|          8|                  2|   1|
# |             2015-08-18|          WABASH AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  2|   1|
# |             2015-08-18|           WACKER DR|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  3|   0|
# |             2015-08-18|           WACKER DR|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  3|   0|
# |             2015-08-18|           WACKER DR|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  3|   0|
# |             2015-08-18|       WASHINGTON ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-18|       WENTWORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-18|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 WET|                3|          8|                  1|   1|
# |             2015-08-19|            111TH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-19|        CANFIELD AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-19|           CERMAK RD|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-19|          CICERO AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          8|                  1|   1|
# |             2015-08-19|         HARRISON ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  2|   1|
# |             2015-08-19|         HARRISON ST|  CLOUDY/OVERCAST|DARKNESS, LIGHTED...|               OTHER|                4|          8|                  2|   1|
# |             2015-08-19|       MILWAUKEE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-19|          ONTARIO ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          8|                  1|   1|
# |             2015-08-19|         SUPERIOR ST|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                4|          8|                  1|   1|
# |             2015-08-20|             87TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-20|             95TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  2|   1|
# |             2015-08-20|             95TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  2|   1|
# |             2015-08-20|        AUGUSTA BLVD|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-20|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-20|       KAMERLING AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-20|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-20|           NORTH AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          8|                  1|   1|
# |             2015-08-21|            BROADWAY|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|       CLEVELAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|       DESPLAINES ST|            CLEAR|                DAWN|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|         FLOURNOY ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|         INDIANA AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|             LAKE ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-21|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-21|           NORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-21|              OAK ST|          UNKNOWN|             UNKNOWN|             UNKNOWN|                6|          8|                  1|   1|
# |             2015-08-21|           WACKER DR|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-22|        AUGUSTA BLVD|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|           CERMAK RD|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|            DAVOL ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|         FRANKLIN ST|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|   INDEPENDENCE BLVD|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|       LAKE PARK AVE|            CLEAR|            DARKNESS|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|    LAKE SHORE DR NB|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  2|   1|
# |             2015-08-22|    LAKE SHORE DR NB|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  2|   1|
# |             2015-08-22|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|        LAVERGNE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|        LAWRENCE AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|       MILWAUKEE AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|             OHIO ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|        ROOSEVELT RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  3|   0|
# |             2015-08-22|        ROOSEVELT RD|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  3|   0|
# |             2015-08-22|        ROOSEVELT RD|            CLEAR|            DAYLIGHT|             UNKNOWN|                7|          8|                  3|   0|
# |             2015-08-22|           SCHOOL ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-22|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  2|   1|
# |             2015-08-22|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  2|   1|
# |             2015-08-23|       CONGRESS PKWY|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  1|   1|
# |             2015-08-23|        GLENLAKE AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                1|          8|                  1|   1|
# |             2015-08-23|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-23|         PRAIRIE AVE|            CLEAR|            DAYLIGHT|                 WET|                1|          8|                  1|   1|
# |             2015-08-23|            SCOTT ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-23|       SHEFFIELD AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-24|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|           CANNON DR|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|         CHESTNUT ST|            CLEAR|            DARKNESS|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|          FOSTER AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|         FRANKLIN ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|         HIGGINS AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|          KEELER AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|    LAKE SHORE DR SB|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|            RUBLE ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-24|            STATE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          8|                  1|   1|
# |             2015-08-25|            103RD ST|            OTHER|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|             99TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|          CICERO AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|         CORCORAN PL|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|           DEVON AVE|            CLEAR|            DARKNESS|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|            MAPLE ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|           NORTH AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-25|             RUSH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          8|                  1|   1|
# |             2015-08-26|             63RD ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          8|                  1|   1|
# |             2015-08-26|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-26|       CHAMPLAIN AVE|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                4|          8|                  1|   1|
# |             2015-08-26|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-26|           FULTON ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  2|   1|
# |             2015-08-26|           FULTON ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          8|                  2|   1|
# |             2015-08-26|          GLADYS AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-26|        JEFFERY BLVD|          UNKNOWN|            DAYLIGHT|             UNKNOWN|                4|          8|                  1|   1|
# |             2015-08-26|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-26|           WACKER DR|            CLEAR|            DAYLIGHT|                 DRY|                4|          8|                  1|   1|
# |             2015-08-26|         WESTERN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          8|                  1|   1|
# |             2015-08-27|            110TH ST|            CLEAR|            DARKNESS|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|             24TH PL|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|             87TH ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|         ILLINOIS ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|        JACKSON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|         LARRABEE ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|     LOWER WACKER DR|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|              OAK ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          8|                  1|   1|
# |             2015-08-27|          WABASH AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                5|          8|                  1|   1|
# |             2015-08-28|          AUSTIN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-28|            CANAL ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-28|            CANAL ST|            CLEAR|                DUSK|                 DRY|                6|          8|                  2|   1|
# |             2015-08-28|         CONGRESS DR|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                6|          8|                  1|   1|
# |             2015-08-28|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 WET|                6|          8|                  2|   1|
# |             2015-08-28|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  2|   1|
# |             2015-08-28|           MORGAN ST|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-28|          ONTARIO ST|            CLEAR|             UNKNOWN|                 DRY|                6|          8|                  1|   1|
# |             2015-08-28|        PARKSIDE AVE|            CLEAR|            DAYLIGHT|                 DRY|                6|          8|                  1|   1|
# |             2015-08-29|         CENTRAL AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 WET|                7|          8|                  2|   1|
# |             2015-08-29|         CENTRAL AVE|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  2|   1|
# |             2015-08-29|         COLUMBUS DR|             RAIN|DARKNESS, LIGHTED...|                 WET|                7|          8|                  1|   1|
# |             2015-08-29|         DEARBORN ST|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  1|   1|
# |             2015-08-29|         DELAWARE PL|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  1|   1|
# |             2015-08-29|          ELSTON AVE|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  1|   1|
# |             2015-08-29|          HUBBARD ST|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  1|   1|
# |             2015-08-29|         ILLINOIS ST|          UNKNOWN|             UNKNOWN|             UNKNOWN|                7|          8|                  1|   1|
# |             2015-08-29|        JACKSON BLVD|            CLEAR|DARKNESS, LIGHTED...|             UNKNOWN|                7|          8|                  1|   1|
# |             2015-08-29|       LAKE SHORE DR|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  1|   1|
# |             2015-08-29|    LAKE SHORE DR SB|  CLOUDY/OVERCAST|            DAYLIGHT|                 WET|                7|          8|                  2|   1|
# |             2015-08-29|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                7|          8|                  2|   1|
# |             2015-08-29|        MICHIGAN AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-29|        OLEANDER AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  1|   1|
# |             2015-08-29|        ROOSEVELT RD|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  2|   1|
# |             2015-08-29|        ROOSEVELT RD|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  2|   1|
# |             2015-08-29|            STATE ST|            CLEAR|DARKNESS, LIGHTED...|                 WET|                7|          8|                  2|   1|
# |             2015-08-29|            STATE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                7|          8|                  2|   1|
# |             2015-08-29|       WASHINGTON ST|             RAIN|            DAYLIGHT|                 WET|                7|          8|                  1|   1|
# |             2015-08-30|             89TH ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|         BELMONT AVE|            CLEAR|            DARKNESS|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|            CANAL ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  2|   1|
# |             2015-08-30|            CANAL ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  2|   1|
# |             2015-08-30|          FOSTER AVE|             RAIN|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|             IOWA ST|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                1|          8|                  1|   1|
# |             2015-08-30|          JACKSON DR|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|         LA SALLE DR|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|     LAKE SHORE DR W|             RAIN|            DARKNESS|                 WET|                1|          8|                  1|   1|
# |             2015-08-30|          MENARD AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|             RUSH ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|      SACRAMENTO AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|        ST LOUIS AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-30|            STATE ST|   FOG/SMOKE/HAZE|            DAYLIGHT|                 DRY|                1|          8|                  1|   1|
# |             2015-08-31|           MAJOR AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-08-31|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                2|          8|                  1|   1|
# |             2015-09-01|             53RD ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|             87TH ST|          UNKNOWN|             UNKNOWN|             UNKNOWN|                3|          9|                  1|   1|
# |             2015-09-01|         CENTRAL AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|   1|
# |             2015-09-01|         CENTRAL AVE|            CLEAR|            DAYLIGHT|             UNKNOWN|                3|          9|                  2|   1|
# |             2015-09-01|         DEARBORN ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|           GOETHE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|          HALSTED ST|            CLEAR|            DARKNESS|                 DRY|                3|          9|                  2|   1|
# |             2015-09-01|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|   1|
# |             2015-09-01|           KOLIN AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|           MARINE DR|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|          ORLEANS ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|         SEDGWICK ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|         SUPERIOR ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-01|           TAYLOR ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|   1|
# |             2015-09-01|           TAYLOR ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  2|   1|
# |             2015-09-01|           WACKER DR|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-02|            103RD ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|             23RD ST|            CLEAR|                DAWN|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|          BELDEN AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|           CERMAK RD|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|       CLAREMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|          HALSTED ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|          HARLEM AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-02|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-02|     NORTH BRANCH ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|       PRINCETON AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|         SHERIDAN RD|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-02|            STATE ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-03|             59TH ST|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|   1|
# |             2015-09-03|          ARCHER AVE|            CLEAR|            DAYLIGHT|             UNKNOWN|                5|          9|                  2|   1|
# |             2015-09-03|          ARCHER AVE|            CLEAR|            DAYLIGHT|             UNKNOWN|                5|          9|                  2|   1|
# |             2015-09-03|         CHICAGO AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|   1|
# |             2015-09-03|DR MARTIN LUTHER ...|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|   1|
# |             2015-09-03|          ELSTON AVE|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|   1|
# |             2015-09-03|             ERIE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                5|          9|                  1|   1|
# |             2015-09-03|    LAKE SHORE DR NB|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  1|   1|
# |             2015-09-03|    LAKE SHORE DR SB|            CLEAR|            DARKNESS|                 DRY|                5|          9|                  2|   1|
# |             2015-09-03|    LAKE SHORE DR SB|            CLEAR|            DAYLIGHT|                 DRY|                5|          9|                  2|   1|
# ...
# |             2015-09-27|        KILBOURN AVE|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|         LARAMIE AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|          MADISON ST|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|         RANDOLPH ST|            CLEAR|             UNKNOWN|             UNKNOWN|                1|          9|                  1|   1|
# |             2015-09-27|           SCHOOL ST|            CLEAR|             UNKNOWN|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|         SHERIDAN RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|        VAN BUREN ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|           WACKER DR|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                1|          9|                  1|   1|
# |             2015-09-27|     WASHINGTON BLVD|            CLEAR|            DAYLIGHT|                 DRY|                1|          9|                  1|   1|
# |             2015-09-28|             71ST ST|            CLEAR|                DUSK|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|             83RD ST|            CLEAR|            DAYLIGHT|             UNKNOWN|                2|          9|                  1|   1|
# |             2015-09-28|       CLEVELAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|      COMMERCIAL AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|   COTTAGE GROVE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|           DEVON AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|          DREXEL AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|         DREXEL BLVD|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|           GRAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|          KEDZIE AVE|            CLEAR|            DAYLIGHT|             UNKNOWN|                2|          9|                  1|   1|
# |             2015-09-28|         KOSTNER AVE|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|    LAKE SHORE DR NB|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|             LAKE ST|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|         LANGLEY AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|      LEAMINGTON AVE|            CLEAR|             UNKNOWN|             UNKNOWN|                2|          9|                  1|   1|
# |             2015-09-28|        MARQUETTE RD|          UNKNOWN|             UNKNOWN|             UNKNOWN|                2|          9|                  1|   1|
# |             2015-09-28|        MICHIGAN AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|           MILLER ST|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|       MILWAUKEE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|          RACINE AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|           TRIPP AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                2|          9|                  1|   1|
# |             2015-09-28|          VERNON AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|       WENTWORTH AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  1|   1|
# |             2015-09-28|         WESTERN AVE|            CLEAR|            DAYLIGHT|                 DRY|                2|          9|                  3|   0|
# |             2015-09-28|         WESTERN AVE|            CLEAR|            DAYLIGHT|             UNKNOWN|                2|          9|                  3|   0|
# |             2015-09-28|         WESTERN AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                2|          9|                  3|   0|
# |             2015-09-29|             64TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|             75TH ST|  CLOUDY/OVERCAST|            DAYLIGHT|                 WET|                3|          9|                  1|   1|
# |             2015-09-29|             78TH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|           ALLEN AVE|            CLEAR|            DARKNESS|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|         CENTRAL AVE|             RAIN|            DAYLIGHT|                 WET|                3|          9|                  1|   1|
# |             2015-09-29|          CHARLES ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|          CICERO AVE|            CLEAR|            DARKNESS|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|           DAMEN AVE|            CLEAR|                DUSK|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|       FULTON MARKET|            OTHER|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|      IRVING PARK RD|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|          KEELER AVE|             RAIN|            DAYLIGHT|                 WET|                3|          9|                  1|   1|
# |             2015-09-29|         LARRABEE ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|          MADISON ST|             RAIN|            DAYLIGHT|                 WET|                3|          9|                  1|   1|
# |             2015-09-29|        MARQUETTE RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|          MENARD AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|   1|
# |             2015-09-29|          MENARD AVE|            CLEAR|             UNKNOWN|                 DRY|                3|          9|                  2|   1|
# |             2015-09-29|          MENDELL ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|        MICHIGAN AVE|             RAIN|            DAYLIGHT|                 WET|                3|          9|                  2|   1|
# |             2015-09-29|        MICHIGAN AVE|          UNKNOWN|             UNKNOWN|                 DRY|                3|          9|                  2|   1|
# |             2015-09-29|           NORTH AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|          NORWOOD ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|          ONTARIO ST|            CLEAR|            DAYLIGHT|                 WET|                3|          9|                  1|   1|
# |             2015-09-29|          PARKER AVE|          UNKNOWN|             UNKNOWN|             UNKNOWN|                3|          9|                  1|   1|
# |             2015-09-29|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|   1|
# |             2015-09-29|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  2|   1|
# |             2015-09-29|         RANDOLPH ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|       SHEFFIELD AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|        ST LOUIS AVE|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|             TROY ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|           WACKER DR|          UNKNOWN|                DUSK|             UNKNOWN|                3|          9|                  1|   1|
# |             2015-09-29|       WASHINGTON ST|            CLEAR|            DAYLIGHT|                 DRY|                3|          9|                  1|   1|
# |             2015-09-29|         WESTERN AVE|            CLEAR|                DUSK|                 DRY|                3|          9|                  2|   1|
# |             2015-09-29|         WESTERN AVE|             RAIN|            DAYLIGHT|                 WET|                3|          9|                  2|   1|
# |             2015-09-30|            103RD ST|            CLEAR|                DUSK|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|             43RD ST|            CLEAR|            DAYLIGHT|             UNKNOWN|                4|          9|                  1|   1|
# |             2015-09-30|             64TH ST|            CLEAR|            DAYLIGHT|                 WET|                4|          9|                  1|   1|
# |             2015-09-30|         ASHLAND AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|         ASHLAND AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|         AUSTIN BLVD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|         BELMONT AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|          CHARLES ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|           CHASE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|          CICERO AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|          CLINTON ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|   COTTAGE GROVE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|   COTTAGE GROVE AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|         DIVISION ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|DR MARTIN LUTHER ...|            CLEAR|            DAYLIGHT|             UNKNOWN|                4|          9|                  1|   1|
# |             2015-09-30|       FULTON MARKET|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|          HAMLET AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|         JEFFERY AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|        JEFFERY BLVD|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|    LAKE SHORE DR NB|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|        LAWNDALE AVE|            CLEAR|                DUSK|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|            LUNA AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|        MARQUETTE RD|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|           MORGAN ST|          UNKNOWN|DARKNESS, LIGHTED...|             UNKNOWN|                4|          9|                  2|   1|
# |             2015-09-30|           MORGAN ST|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|        PETERSON AVE|  CLOUDY/OVERCAST|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|        PETERSON AVE|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  2|   1|
# |             2015-09-30|          PULASKI RD|            CLEAR|            DAYLIGHT|                 DRY|                4|          9|                  1|   1|
# |             2015-09-30|           ROSCOE ST|            CLEAR|DARKNESS, LIGHTED...|                 DRY|                4|          9|                  1|   1|
# +-----------------------+--------------------+-----------------+--------------------+--------------------+-----------------+-----------+-------------------+----+
# only showing top 1000 rows

# %%
# ################################################################################################################################################################
# ################################################################################################################################################################
# ################################################################################################################################################################
# ################################################################################################################################################################
# ################################################################################################################################################################

# making the model

# Encoding categorical features
indexers = [StringIndexer(inputCol=col, outputCol=col+"_index").fit(final_df) for col in ['STREET_NAME', 'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'ROADWAY_SURFACE_COND']]
pipeline = Pipeline(stages=indexers)
encoded_df = pipeline.fit(final_df).transform(final_df)

# %%
# Assemble features into a vector
assembler = VectorAssembler(inputCols=['STREET_NAME_index', 'WEATHER_CONDITION_index', 'LIGHTING_CONDITION_index', 'ROADWAY_SURFACE_COND_index', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH'], outputCol="features")
assembled_df = assembler.transform(encoded_df)

# Split the data into training and testing sets
train_data, test_data = assembled_df.randomSplit([0.8, 0.2], seed=42)

# Train RandomForestClassifier model
rf = RandomForestClassifier(labelCol="SAFE", featuresCol="features", numTrees=10, maxBins=2048)
model = rf.fit(train_data)

# Make predictions
predictions = model.transform(test_data)

# Evaluate the model
evaluator = BinaryClassificationEvaluator(labelCol="SAFE")
accuracy = evaluator.evaluate(predictions)
print("Accuracy:", accuracy)

# ################################################################################################################################################################
# ################################################################################################################################################################
# ################################################################################################################################################################
# ################################################################################################################################################################
# ################################################################################################################################################################
# Out:
# Accuracy: 0.7964517857575121

# %%
# Fit the pipeline on the training data, to use it as many times for testing, without it taking much time
pipeline_model = pipeline.fit(final_df)

# %%
# testing the model

# Define the input data
sample_data = {
    'STREET_NAME': 'HALSTED ST',
    'WEATHER_CONDITION': 'CLEAR',
    'LIGHTING_CONDITION': 'DAYLIGHT',
    'ROADWAY_SURFACE_COND': 'DRY',
    'CRASH_DAY_OF_WEEK': 5,
    'CRASH_MONTH': 8
}

# Create a DataFrame with the sample data
sample_df = spark.createDataFrame([sample_data])

# Index the categorical columns
# indexers = [StringIndexer(inputCol=col, outputCol=col+"_index").fit(final_df) for col in ['STREET_NAME', 'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'ROADWAY_SURFACE_COND']]
# pipeline = Pipeline(stages=indexers)
# indexed_sample_df = pipeline.fit(final_df).transform(sample_df)

# Transform the sample data using the fitted pipeline model
indexed_sample_df = pipeline_model.transform(sample_df)



# Assemble features into a vector
# assembler = VectorAssembler(inputCols=['STREET_NAME_index', 'WEATHER_CONDITION_index', 'LIGHTING_CONDITION_index', 'ROADWAY_SURFACE_COND_index', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH'], outputCol="features")
assembled_sample_df = assembler.transform(indexed_sample_df)

# Make predictions
predictions = model.transform(assembled_sample_df)

# Display the prediction
prediction_value = predictions.select("prediction").collect()[0][0]
print("Predicted SAFE value:", int(prediction_value))
# Out:
# Predicted SAFE value: 1

# %%
model.save('/content/drive/MyDrive/AccidentModel')

# dump(model, '/content/drive/MyDrive/collisionDetectionModel.joblib')

# Save the model using dill
# with open('/content/drive/MyDrive/collisionDetectionModel.pkl', 'wb') as file:
#     dill.dump(model, file)
